# %%
# !wget https://raw.githubusercontent.com/preprocessed-connectomes-project/abide/master/download_abide_preproc.py

# %%
# !python download_abide_preproc.py -a -d rois_aal -p ccs -s nofilt_noglobal -o .

# %%
# !python download_abide_preproc.py -a -d rois_cc200 -p ccs -s nofilt_noglobal -o .

# %%
# !python download_abide_preproc.py -a -d rois_cc400 -p ccs -s nofilt_noglobal -o .

# %%
# !python download_abide_preproc.py -a -d rois_dosenbach160 -p ccs -s nofilt_noglobal -o .

# %%
# !python download_abide_preproc.py -a -d rois_ez -p ccs -s nofilt_noglobal -o .

# %%
# !python download_abide_preproc.py -a -d rois_ho -p ccs -s nofilt_noglobal -o .

# %%
# !python download_abide_preproc.py -a -d rois_tt -p ccs -s nofilt_noglobal -o .
